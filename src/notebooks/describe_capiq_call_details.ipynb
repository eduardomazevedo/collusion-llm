# %%
import pandas as pd
import config
df = pd.read_feather(f'{config.ROOT}/data/transcript-detail.feather')

# %%
df.head()
# Out:
#    companyid    keydevid  transcriptid  \
# 0       <NA>  1888144182       3214308
# 1       <NA>  1888144182       3214327
# 2       <NA>  1888144182       3214420
# 3      18511   115648395         93162
# 4      18511   115648395         93403
#
#                                             headline mostimportantdateutc  \
# 0                                               None                 None
# 1                                               None                 None
# 2                                               None                 None
# 3  3i Group plc, H1 2011 Earnings Call, Nov 11, 2010           2010-11-11
# 4  3i Group plc, H1 2011 Earnings Call, Nov 11, 2010           2010-11-11
#
#   mostimportanttimeutc keydeveventtypeid keydeveventtypename   companyname  \
# 0                 None               NaN                 NaN          None
# 1                 None               NaN                 NaN          None
# 2                 None               NaN                 NaN          None
# 3             09:45:00              48.0      Earnings Calls  3i Group plc
# 4             09:45:00              48.0      Earnings Calls  3i Group plc
#
#   transcriptcollectiontypeid transcriptcollectiontypename  \
# 0                          7            Spellchecked Copy
# 1                          7            Spellchecked Copy
# 2                          2                  Edited Copy
# 3                          7            Spellchecked Copy
# 4                          2                  Edited Copy
#
#   transcriptpresentationtypeid transcriptpresentationtypename  \
# 0                            4                    Preliminary
# 1                            4                    Preliminary
# 2                            5                          Final
# 3                            4                    Preliminary
# 4                            5                          Final
#
#   transcriptcreationdate_utc transcriptcreationtime_utc  audiolengthsec
# 0                 2024-08-06                   17:06:26          3865.0
# 1                 2024-08-06                   17:19:28          3865.0
# 2                 2024-08-06                   18:10:32          3865.0
# 3                 2011-01-20                   20:21:55          2945.0
# 4                 2011-01-21                   00:22:45          2945.0

# %%
# Uhaul calls
df_uhaul = df[df['companyid'] == 345588]
df_uhaul
# Out:
#        companyid    keydevid  transcriptid  \
# 54769     345588     5139015          9063
# 54770     345588     5509699          9064
# 54771     345588     5724462         11154
# 54772     345588     5967462         15056
# 54773     345588     6188940         16857
# ...          ...         ...           ...
# 55063     345588  1888764109       3219861
# 55064     345588  1890769226       3231089
# 55065     345588  1890769226       3231183
# 55066     345588  1901586470       3302057
# 55067     345588  1901586470       3302808
#
#                                                 headline mostimportantdateutc  \
# 54769         AMERCO, Q3 2008 Earnings Call, Feb-07-2008           2008-02-07
# 54770         AMERCO, Q4 2008 Earnings Call, Jun-05-2008           2008-06-05
# 54771         AMERCO, Q1 2009 Earnings Call, Aug-07-2008           2008-08-07
# 54772         AMERCO, Q2 2009 Earnings Call, Nov-06-2008           2008-11-06
# 54773         AMERCO, Q3 2009 Earnings Call, Feb-05-2009           2009-02-05
# ...                                                  ...                  ...
# 55063  U-Haul Holding Company, Q1 2025 Earnings Call,...           2024-08-08
# 55064  U-Haul Holding Company - Shareholder/Analyst Call           2024-08-15
# 55065  U-Haul Holding Company - Shareholder/Analyst Call           2024-08-15
# 55066  U-Haul Holding Company, Q2 2025 Earnings Call,...           2024-11-07
# 55067  U-Haul Holding Company, Q2 2025 Earnings Call,...           2024-11-07
#
#       mostimportanttimeutc keydeveventtypeid        keydeveventtypename  \
# 54769             15:00:00              48.0             Earnings Calls
# 54770             15:00:00              48.0             Earnings Calls
# 54771             15:00:00              48.0             Earnings Calls
# 54772             15:00:00              48.0             Earnings Calls
# 54773             15:00:00              48.0             Earnings Calls
# ...                    ...               ...                        ...
# 55063             15:00:00              48.0             Earnings Calls
# 55064             18:00:00              50.0  Shareholder/Analyst Calls
# 55065             18:00:00              50.0  Shareholder/Analyst Calls
# 55066             15:00:00              48.0             Earnings Calls
# 55067             15:00:00              48.0             Earnings Calls
#
#                   companyname transcriptcollectiontypeid  \
# 54769  U-Haul Holding Company                          6
# 54770  U-Haul Holding Company                          6
# 54771  U-Haul Holding Company                          6
# 54772  U-Haul Holding Company                          6
# 54773  U-Haul Holding Company                          6
# ...                       ...                        ...
# 55063  U-Haul Holding Company                          2
# 55064  U-Haul Holding Company                          7
# 55065  U-Haul Holding Company                          2
# 55066  U-Haul Holding Company                          7
# 55067  U-Haul Holding Company                          2
#
#       transcriptcollectiontypename transcriptpresentationtypeid  \
# 54769               SA Edited Copy                            5
# 54770               SA Edited Copy                            5
# 54771               SA Edited Copy                            5
# 54772               SA Edited Copy                            5
# 54773               SA Edited Copy                            5
# ...                            ...                          ...
# 55063                  Edited Copy                            5
# 55064            Spellchecked Copy                            4
# 55065                  Edited Copy                            5
# 55066            Spellchecked Copy                            4
# 55067                  Edited Copy                            5
#
#       transcriptpresentationtypename transcriptcreationdate_utc  \
# 54769                          Final                 2008-06-20
# 54770                          Final                 2008-06-20
# 54771                          Final                 2008-08-22
# 54772                          Final                 2008-11-25
# 54773                          Final                 2009-02-17
# ...                              ...                        ...
# 55063                          Final                 2024-08-08
# 55064                    Preliminary                 2024-08-15
# 55065                          Final                 2024-08-15
# 55066                    Preliminary                 2024-11-07
# 55067                          Final                 2024-11-07
#
#       transcriptcreationtime_utc  audiolengthsec
# 54769                   05:17:11             NaN
# 54770                   05:17:11             NaN
# 54771                   22:01:24             NaN
# 54772                   17:34:01             NaN
# 54773                   19:29:02             NaN
# ...                          ...             ...
# 55063                   19:22:51          3187.0
# 55064                   22:05:22          4865.0
# 55065                   23:54:28          4865.0
# 55066                   16:21:55          1693.0
# 55067                   21:14:54          1693.0
#
# [298 rows x 16 columns]

# %%
df.dtypes
# Out:
# companyid                            Int64
# keydevid                             Int64
# transcriptid                         Int64
# headline                            object
# mostimportantdateutc                object
# mostimportanttimeutc                object
# keydeveventtypeid                 category
# keydeveventtypename               category
# companyname                         object
# transcriptcollectiontypeid        category
# transcriptcollectiontypename      category
# transcriptpresentationtypeid      category
# transcriptpresentationtypename    category
# transcriptcreationdate_utc          object
# transcriptcreationtime_utc          object
# audiolengthsec                     float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#                companyid          keydevid    transcriptid  \
# count          1624943.0         1624946.0       1624946.0
# unique              <NA>              <NA>            <NA>
# top                 <NA>              <NA>            <NA>
# freq                <NA>              <NA>            <NA>
# mean     54425012.171368  741703817.083026  1541546.843458
# std     149202227.869962  612812949.629492   925997.034469
# min              18511.0               0.0           108.0
# 25%             288195.0       274912787.0        740883.5
# 50%             875395.0       573636904.0       1546767.0
# 75%           24558792.0      706286137.75      2275325.75
# max         1900954228.0      2147481247.0       3324225.0
#
#                                headline mostimportantdateutc  \
# count                           1624943              1624943
# unique                           454109                 5419
# top     Salesforce, Inc. - Special Call           2020-05-07
# freq                                392                 3596
# mean                                NaN                  NaN
# std                                 NaN                  NaN
# min                                 NaN                  NaN
# 25%                                 NaN                  NaN
# 50%                                 NaN                  NaN
# 75%                                 NaN                  NaN
# max                                 NaN                  NaN
#
#        mostimportanttimeutc  keydeveventtypeid keydeveventtypename  \
# count               1624943          1624943.0             1624943
# unique                  434               19.0                  19
# top                14:00:00               48.0      Earnings Calls
# freq                 159414          1161115.0             1161115
# mean                    NaN                NaN                 NaN
# std                     NaN                NaN                 NaN
# min                     NaN                NaN                 NaN
# 25%                     NaN                NaN                 NaN
# 50%                     NaN                NaN                 NaN
# 75%                     NaN                NaN                 NaN
# max                     NaN                NaN                 NaN
#
#              companyname  transcriptcollectiontypeid  \
# count            1624178                   1624946.0
# unique             20221                         9.0
# top     Salesforce, Inc.                         2.0
# freq                1355                    448171.0
# mean                 NaN                         NaN
# std                  NaN                         NaN
# min                  NaN                         NaN
# 25%                  NaN                         NaN
# 50%                  NaN                         NaN
# 75%                  NaN                         NaN
# max                  NaN                         NaN
#
#        transcriptcollectiontypename  transcriptpresentationtypeid  \
# count                       1624946                     1624946.0
# unique                            9                           2.0
# top                     Edited Copy                           5.0
# freq                         448171                     1167801.0
# mean                            NaN                           NaN
# std                             NaN                           NaN
# min                             NaN                           NaN
# 25%                             NaN                           NaN
# 50%                             NaN                           NaN
# 75%                             NaN                           NaN
# max                             NaN                           NaN
#
#        transcriptpresentationtypename transcriptcreationdate_utc  \
# count                         1624946                    1624946
# unique                              2                       5728
# top                             Final                 2008-06-20
# freq                          1167801                       6285
# mean                              NaN                        NaN
# std                               NaN                        NaN
# min                               NaN                        NaN
# 25%                               NaN                        NaN
# 50%                               NaN                        NaN
# 75%                               NaN                        NaN
# max                               NaN                        NaN
#
#        transcriptcreationtime_utc  audiolengthsec
# count                     1624946    1.582309e+06
# unique                      86387             NaN
# top                      19:50:05             NaN
# freq                          532             NaN
# mean                          NaN    3.303785e+03
# std                           NaN    4.137065e+04
# min                           NaN    0.000000e+00
# 25%                           NaN    1.953000e+03
# 50%                           NaN    2.679000e+03
# 75%                           NaN    3.584000e+03
# max                           NaN    2.115610e+07

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extract the year from the 'mostimportantdateutc' column
df['year'] = pd.to_datetime(df['mostimportantdateutc']).dt.year

# Plot the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['year'], bins=range(2004, 2026), kde=False)
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Histogram of Most Important Dates by Year')
plt.show()

# %%
# Convert audiolengthsec to minutes
df['audiolengthmin'] = df['audiolengthsec'] / 60

# Plot the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['audiolengthmin'].dropna(), bins=range(0, 301), kde=False)
plt.xlabel('Audio Length (minutes)')
plt.ylabel('Frequency')
plt.title('Histogram of Audio Length in Minutes')
plt.xlim(0, 200)
plt.show()
