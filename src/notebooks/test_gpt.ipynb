# %%
import config
import modules.gpt as gpt
import json

# %%
result = gpt.run_completion(prompt_name = 'binary', transcript_text = 'hello! i want to collude')

# %%
result
# Out:
# {'indicator': False, 'excerpts': []}

# %%
result
# Out:
# {'indicator': False, 'excerpts': []}

# %%
test_ids = [9063, 15056]
results = gpt.get_responses(prompt_name = 'binary', transcript_ids = test_ids)
# Out:
# Loading library list...
# Done
# WRDS connection established.

# %%
results
# Out:
# {9063: {'indicator': True,
#   'excerpts': ['"So in a way I am kind of force to respond, although, for the last 90 days I\'ve encouraged everybody who has rate setting authority in the company to give it more time and see if you can get it to stabilized. In other words, hold the line at a little higher."',
#    '"And that\'s very -- if it starts to affect share I am going to respond, that\'s all. If the customer doesn\'t care if it\'s $10 and the customer doesn\'t care, but on the other hand, the only reason they do it is if they thought it affected share."',
#    '"But a market where I don\'t see a lot of competition, I\'m trying to exhibit some price leadership and even in several quarter markets that are highly competitive, I\'m trying to exhibit some price leadership because, as I think you have found on your own, there are markets that are being priced well below the cost providing service."',
# ...
