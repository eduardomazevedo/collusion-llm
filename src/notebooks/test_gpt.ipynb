# %%
import config
import modules.gpt as gpt
import json

# %%
result = gpt.run_completion(prompt_name = 'binary', transcript_text = 'hello! i want to collude')

# %%
result
# Out:
# {'indicator': False, 'excerpts': []}

# %%
result
# Out:
# {'indicator': False, 'excerpts': []}

# %%
test_ids = [9063, 15056]
results = gpt.get_responses(prompt_name = 'binary', transcript_ids = test_ids)
# Out:
# Loading library list...
# Done
# WRDS connection established.

# %%
results
# Out:
# {9063: {'indicator': True,
#   'excerpts': ['"I intend for us to continue to do this, however, overall rates remain depressed."',
#    '"I\'m trying to exhibit some price leadership and even in several quarter markets that are highly competitive, I\'m trying to exhibit some price leadership because, as I think you have found on your own, there are markets that are being priced well below the cost providing service."',
#    '"If the customer doesn\'t care if it\'s $10 and the customer doesn\'t care, but on the other hand, the only reason they do it is if they thought it affected share."',
#    '"So we have to go in every market where they are really not competing with us or every size of truck for they are really not competing, we need to try to get a fair price and which I think we did an okay job of that in the third quarter."',
#    '"I believe the budget Truck Rental Company is trying to take U-Haul\'s price in every single corridor and drop it, one or two, or three or four whatever number they can percent."',
#    '"If they cut a dollar, because the dollar I believe is three times the transactions roughly. It\'s no fun."',
#    '"It\'s when somebody decides they have to gain share from somebody that you get this kind of turbulence. That results in no economic gains for the group, in fact, probably an economic loss."']},
#  15056: {'indicator': True,
#   'excerpts': ['"Competitor rates continue to have a negative influence on our revenues. While our revenue per transaction statistics over the last two quarters indicate a softening trend and price decline. Competitive rate pressures still weigh on our result."',
#    '"I do not see discounts up, and we have not yet lowered prices at more than one or two stores, if at one or two. We are very, I do not know what to say, obstinate on that. So, I am not seeing prices decline."',
#    '"It is very common for a guy to get the idea, look, if I drop my price, I will get all the business. So, I would expect to see some of that, especially given all the product that came on board in the last three or four years."',
#    '"We actively encourage people in the self storage business to maintain prices obviously, and we were not about to be the one who has the reputation for dumping price as well."',
#    '"I think we could argue it is better than it was a year, a year and a half ago. It still is, Jim, that people who are struggling to do business will go five or 10 back if you respirate. They will ask you a question like, are you a member AARP or a member of AAA or are you a packer fan?"']}}
