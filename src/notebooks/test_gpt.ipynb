# %%
import config
import modules.gpt as gpt

# %%
result = gpt.get_response('binary', 'hello! i want to collude')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 result = gpt.get_response('hello! i want to collude', 'binary')
#
# File ~/projects/collusion-llm/modules/gpt.py:46, in get_response(promp_name, transcript_text)
#      42 def get_response(promp_name, transcript_text):
#      43     completion = get_client().beta.chat.completions(
#      44         model = _model,
#      45         messages=[
# ---> 46             {"role": "system", "content": prompts[promp_name]['system_message']},
#      47             {"role": "user", "content": transcript_text}
#      48         ],
#      49         response_format = prompts[promp_name]['response_format']
#      50     )
#
# KeyError: 'hello! i want to collude'
