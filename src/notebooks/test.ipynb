# %%
import os
import config

print(os.getcwd())
print(config.OPENAI_API_KEY)
# Out:
# /Users/eduaze/projects/collusion-llm
# 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

# %%
import wrds
print (wrds.Connection)
# Out:
# <class 'wrds.sql.Connection'>

# %%
import wrds
conn = wrds.Connection(wrds_username=config.WRDS_USERNAME, password=config.WRDS_PASSWORD)
# Out:
# Loading library list...
# Done
